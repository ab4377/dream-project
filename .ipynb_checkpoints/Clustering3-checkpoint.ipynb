# %%
import pandas as pd
import os
import numpy as np
import math
from scipy.fftpack import fft
import mlpy
import json
import matplotlib.pyplot as plt

walking_outbound_path = "../dataset/accel_motion_walking_outbound"
meta_data_location = "../meta-data.csv"
sampling_frequency = 100

def load_data():
    meta_data = pd.read_csv(meta_data_location)
    class_label_map = {}
    for index,row in meta_data.iterrows():
        class_label_map[row["outbound_walk_json_file"]] = row["medTimepoint"]
    X = []
    class_label = []
    file_names = os.listdir(walking_outbound_path)
    for file_name in file_names:
        if file_name.endswith(".tmp"):
            x = pd.read_json(walking_outbound_path + "/" + file_name)
            X.append(x)
            class_label.append(class_label_map[file_name])
    return (X,class_label)

def get_accel_magnitude(x,y,z):
    return math.sqrt(x**2 + y**2 + z**2)

def get_frequency_components(x):
    N = len(x)
    y = fft(x)
    a = np.abs(y[0:N//2])
    f = np.linspace(0,sampling_frequency/2,N//2)
    return (f,a)

def dtw_distance(x,y):
    return mlpy.dtw_std(x,y,dist_only=True)

def to_json(distance_matrix,class_labels):
    minimum = distance_matrix.min(axis=0).min()
    maximum = distance_matrix.max(axis=1).max()

    #new range
    low = 1.0
    high = 10.0
    #group labels
    group_code = dict(zip(list(set(class_labels)),[1,2,3,4]))
    data = {}
    data["nodes"] = []
    data["links"] = []
    for label in class_labels:
        datum = {}
        datum["id"] = label
        datum["group"] = group_code[label]
        data["nodes"].append(datum)

    N = distance_matrix.shape[0]
    for i in range(N):
        for j in range(i+1,N):
            datum = {}
            datum["source"] = class_labels[i]
            datum["target"] = class_labels[j]
            datum["value"] = int(low + (distance_matrix[i][j] - minimum)*(high - low)/(maximum - minimum))
            data["links"].append(datum)
    with open('data.json', 'w') as outfile:
        json.dump(data, outfile)

def get_average_distance(distance_matrix,class_labels):
    group_code = dict(zip(list(set(class_labels)), [1, 2, 3, 4]))
    print(group_code)
    distance = np.zeros(shape=(len(group_code),len(group_code)),dtype=float)
    total_examples = np.zeros(shape=(len(group_code),len(group_code)))
    (M,N) = distance_matrix.shape
    for i in range(N):
        for j in range(i+1,N):
            distance[group_code[class_labels[i]]-1][group_code[class_labels[j]]-1] += distance_matrix[i][j]
            total_examples[group_code[class_labels[i]]-1][group_code[class_labels[j]]-1] += 1

    print("Till here")
    print(distance)
    print(total_examples)
    distance = distance/total_examples

    #plt.imshow(distance, cmap='hot', interpolation='nearest')
    #plt.show()


if __name__ == '__main__':
    (X,class_label) = load_data()
    Z = []
    for x in X:
        accel = []
        for index,row in x.iterrows():
            accel.append(get_accel_magnitude(row["x"],row["y"],row["z"]))
        accel = np.array(accel)
        Z.append(accel)


    print('Computing the DTW distances...')
    N = len(Z)
    distance_matrix = np.ndarray(shape=(N,N))
    for i in range(N):
        for j in range(i+1,N):
            distance_matrix[i][j] = dtw_distance(Z[i],Z[j])

    #distance_matrix = distance_matrix + distance_matrix.T
    print("Done!")
    print("Creating TSV data...")
    #to_json(distance_matrix,class_label)
    get_average_distance(distance_matrix,class_label)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-f3c01ec5d712> in <module>()
#      90
#      91 if __name__ == '__main__':
# ---> 92     (X,class_label) = load_data()
#      93     Z = []
#      94     for x in X:
#
# <ipython-input-1-f3c01ec5d712> in load_data()
#      13
#      14 def load_data():
# ---> 15     meta_data = pd.read_csv(meta_data_location)
#      16     class_label_map = {}
#      17     for index,row in meta_data.iterrows():
#
# /usr/local/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# /usr/local/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# /usr/local/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# /usr/local/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# /usr/local/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'../meta-data.csv' does not exist

# %%
meta_data_location = "../meta-data.csv"
pd.read_csv(meta_data_location)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2fd959d7a63e> in <module>()
#       1 meta_data_location = "../meta-data.csv"
# ----> 2 pd.read_csv(meta_data_location)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
meta_data_location = "../meta-data.csv"
pd.read_csv(meta_data_location)
# Out:
#     Unnamed: 0                              recordId  \
# 0            0  a3e54d84-360e-4e8a-9534-de188d5fa9e1
# 1            1  27d5ffdd-536e-4f2d-b478-74bbd520e9f7
# 2            2  cdd76ffc-9607-4106-b806-2fa29ad282f4
# 3            3  ba735eb0-0639-4392-8d4d-f87b06c7b7e6
# 4            4  2344a520-81df-4166-9f63-09343c502a21
# 5            5  a5c41f42-8715-4dfc-abf8-e2f3dd010c89
# 6            6  5f852dd2-85d9-4f5a-9757-8c20bcc2c62b
# 7            7  3dbcb46c-e0bf-49fd-aa9f-3922449d1eef
# 8            8  d2187281-7266-4d8f-a394-6f5b9123bf72
# 9            9  353892f0-f92d-4229-be8f-78e7f78480c4
# 10          10  73cad66b-6a2c-4412-a982-90679383461f
# 11          11  870c225a-cff3-4903-8703-0021c321191b
# 12          12  bba903e2-dfa5-4e74-8b9b-41105af1be32
# 13          13  9df9391e-e1f7-46ca-8496-736ae2f757c9
# 14          14  6b2e3b5f-d000-435b-86c8-50355bd97bff
# 15          15  ed3c2ecb-8118-4e3b-b584-4fb7927d3206
# 16          16  e62ecc5c-3c31-44f3-8967-44102fbd9446
# 17          17  eadb5434-b6fa-4282-aa21-2fa978e4f2dd
# 18          18  f15d4b37-a767-44d1-b847-35a76dc08196
# 19          19  c436b9cd-c89f-409f-8939-11438e5e8913
# 20          20  3bbe73e9-151c-4954-a07c-11213d6dde85
# 21          21  57732f79-2b07-482e-a642-ce96e68aa5e3
# 22          22  c6844ae2-e7ac-42f6-92d7-f0c5c8354e1f
# 23          23  727c98f1-e023-4a16-99f9-14a1809344f9
# 24          24  1560f65d-4386-4d98-9889-58f149c2da17
# 25          25  0ccb977e-e99d-4d99-b18f-80390d4773b6
# 26          26  39748459-c70f-407f-b9ae-58d82231fcef
# 27          27  d6308802-0aeb-46dc-89e2-c910522b649a
# 28          28  3e094bcd-a13f-41f0-973c-3a1fedf16075
# 29          29  a8816361-37dc-4e3c-b6fb-f6c7b5a8ac8f
# ..         ...                                   ...
# 70          70  b75d181a-ae82-4775-ae17-0a5ba04c406d
# 71          71  ad22aa82-e55e-4148-9ce1-503e053371f6
# 72          72  4feeed54-0039-4259-b9a6-87e19f01566e
# 73          73  dc50b4be-71b3-49f6-90c5-bc1389306e00
# 74          74  ff3a6365-c9f4-4ce7-ae70-781381d63001
# 75          75  a3940855-91b6-405a-8d5b-a6d2832444ee
# 4      version 1.0, build 7         iPhone 6
# 5      version 1.0, build 7    iPhone 6 Plus
# 6      version 1.0, build 7    iPhone 6 Plus
# 7      version 1.0, build 7    iPhone 6 Plus
# 8      version 1.0, build 7    iPhone 6 Plus
# 9      version 1.0, build 7    iPhone 6 Plus
# 10     version 1.0, build 7    iPhone 6 Plus
# 11     version 1.0, build 7    iPhone 6 Plus
# 12     version 1.0, build 7    iPhone 6 Plus
# 13     version 1.0, build 7  iPhone 5s (GSM)
# 14  version 1.0.5, build 12  iPhone 5s (GSM)
# 15     version 1.0, build 7  iPhone 5s (GSM)
# 16     version 1.0, build 7  iPhone 5s (GSM)
# 17     version 1.0, build 7  iPhone 5s (GSM)
# 18     version 1.0, build 7  iPhone 5s (GSM)
# 19     version 1.0, build 7  iPhone 5s (GSM)
# 20     version 1.0, build 7  iPhone 5s (GSM)
# 21     version 1.0, build 7  iPhone 5s (GSM)
# 22     version 1.0, build 7  iPhone 5s (GSM)
# 23     version 1.0, build 7  iPhone 5s (GSM)
# 24     version 1.0, build 7  iPhone 5s (GSM)
# 25     version 1.0, build 7  iPhone 5s (GSM)
# 26     version 1.0, build 7  iPhone 5s (GSM)
# 27     version 1.0, build 7  iPhone 5s (GSM)
# 28     version 1.0, build 7  iPhone 5s (GSM)
# 29     version 1.0, build 7  iPhone 5s (GSM)
# ..                      ...              ...
# 70  version 1.0.5, build 12  iPhone 5s (GSM)
# 71  version 1.0.5, build 12  iPhone 5s (GSM)
# 72  version 1.0.5, build 12  iPhone 5s (GSM)
# 73  version 1.0.5, build 12  iPhone 5s (GSM)
# 74  version 1.0.5, build 12  iPhone 5s (GSM)
# 75  version 1.0.5, build 12  iPhone 5s (GSM)
# 76  version 1.0.5, build 12  iPhone 5s (GSM)
# 77  version 1.0.5, build 12  iPhone 5s (GSM)
# 78  version 1.0.5, build 12  iPhone 5s (GSM)
# 79  version 1.0.5, build 12  iPhone 5s (GSM)
# 80  version 1.0.5, build 12  iPhone 5s (GSM)
# 81  version 1.0.5, build 12  iPhone 5s (GSM)
# 82  version 1.0.5, build 12  iPhone 5s (GSM)
# 83  version 1.0.5, build 12  iPhone 5s (GSM)
# 84  version 1.0.5, build 12  iPhone 5s (GSM)
# 85  version 1.0.5, build 12  iPhone 5s (GSM)
# 86  version 1.0.5, build 12  iPhone 5s (GSM)
# 87  version 1.0.5, build 12  iPhone 5s (GSM)
# 88  version 1.0.5, build 12  iPhone 5s (GSM)
# 89  version 1.0.5, build 12  iPhone 5s (GSM)
# 90  version 1.0.5, build 12  iPhone 5s (GSM)
# 91  version 1.0.5, build 12  iPhone 5s (GSM)
# 92  version 1.0.5, build 12  iPhone 5s (GSM)
# 93  version 1.0.5, build 12  iPhone 5s (GSM)
# 94  version 1.0.5, build 12  iPhone 5s (GSM)
# 95  version 1.0.5, build 12  iPhone 5s (GSM)
# 96  version 1.0.5, build 12  iPhone 5s (GSM)
# 97  version 1.0.5, build 12  iPhone 5s (GSM)
# 98  version 1.0.5, build 12  iPhone 5s (GSM)
# 94                             3530290.0
# 95                             3542557.0
# 96                             3545099.0
# 97                             3539441.0
# 98                             3552098.0
# 99                             3552388.0
#
#                                       medTimepoint       idx  \
# 0               I don't take Parkinson medications    1401_0
# 1               I don't take Parkinson medications   19613_9
# 2               I don't take Parkinson medications    2570_1
# 3               I don't take Parkinson medications    2573_1
# 4               I don't take Parkinson medications    2574_1
# 5               I don't take Parkinson medications    2891_1
# 6               I don't take Parkinson medications    3421_1
# 7               I don't take Parkinson medications    3761_1
# 8               I don't take Parkinson medications    4360_2
# 9               I don't take Parkinson medications    4493_2
# 10              I don't take Parkinson medications    5941_2
# 11              I don't take Parkinson medications    7890_3
# 12         Immediately before Parkinson medication    7155_3
# 13                                    Another time   15185_6
# 14                                    Another time  24683_11
# 15              I don't take Parkinson medications    2838_1
# 16              I don't take Parkinson medications    3884_1
# 17              I don't take Parkinson medications    3886_1
# 18              I don't take Parkinson medications    4671_2
# 19              I don't take Parkinson medications    4672_2
# 20              I don't take Parkinson medications    4675_2
# 21              I don't take Parkinson medications    7485_3
# 22              I don't take Parkinson medications    7488_3
# 23              I don't take Parkinson medications    7491_3
# 24              I don't take Parkinson medications    8018_3
# 25              I don't take Parkinson medications    8020_3
# 26              I don't take Parkinson medications    8022_3
# 27              I don't take Parkinson medications    8498_3
# 28              I don't take Parkinson medications    8501_3
# 29              I don't take Parkinson medications    3802_1
# ..                                             ...       ...
# 70                                    Another time   19149_8
# 71                                    Another time   19150_8
# 72                                    Another time   19151_8
# 73  Just after Parkinson medication (at your best)   19610_9
# 74  Just after Parkinson medication (at your best)   19611_9
# 75  Just after Parkinson medication (at your best)   19612_9
# 76  Just after Parkinson medication (at your best)   20069_9
# 77  Just after Parkinson medication (at your best)   20070_9
# 78  Just after Parkinson medication (at your best)   20071_9
# 79                                    Another time   20378_9
# 80                                    Another time   20379_9
# 81                                    Another time   20380_9
# 82         Immediately before Parkinson medication   20528_9
# 83         Immediately before Parkinson medication   20529_9
# 84         Immediately before Parkinson medication   20530_9
# 85                                    Another time   20755_9
# 86                                    Another time   20756_9
# 87                                    Another time   20757_9
# 88  Just after Parkinson medication (at your best)   21556_9
# 89  Just after Parkinson medication (at your best)   21557_9
# 90  Just after Parkinson medication (at your best)   21558_9
# 91                                    Another time  22539_10
# 92                                    Another time  23183_10
# 93                                    Another time  23184_10
# 94                                    Another time  23185_10
# 95                                    Another time  23348_10
# 96                                    Another time  23349_10
# 97                                    Another time  23350_10
# 98  Just after Parkinson medication (at your best)  23512_10
# 99  Just after Parkinson medication (at your best)  23513_10
#
#                               outbound_walk_json_file
# 0   accel_walking_outbound.json.items-7ea6f300-121...
# 1   accel_walking_outbound.json.items-a503b74f-640...
# 2   accel_walking_outbound.json.items-1295ac02-32a...
# 3   accel_walking_outbound.json.items-20ada1dc-ec1...
# 4   accel_walking_outbound.json.items-fc572b63-451...
# 5   accel_walking_outbound.json.items-d61479c7-a77...
# 6   accel_walking_outbound.json.items-d26584d1-034...
# 7   accel_walking_outbound.json.items-8743d451-aa4...
# 8   accel_walking_outbound.json.items-540c6d36-775...
# 9   accel_walking_outbound.json.items-49af2a0d-fb4...
# 10  accel_walking_outbound.json.items-566620f2-172...
# 11  accel_walking_outbound.json.items-ba1e680a-1e8...
# 12  accel_walking_outbound.json.items-edabdf5f-a46...
# 13  accel_walking_outbound.json.items-b4be3da3-91b...
# 14  accel_walking_outbound.json.items-c31b7f00-a93...
# 15  accel_walking_outbound.json.items-a9554122-96b...
# 16  accel_walking_outbound.json.items-a7c2b38e-b27...
# 17  accel_walking_outbound.json.items-184e7ab7-30a...
# 18  accel_walking_outbound.json.items-098b4812-80f...
# 19  accel_walking_outbound.json.items-2dd0c7c6-ace...
# 20  accel_walking_outbound.json.items-c9b4fea9-caa...
# 21  accel_walking_outbound.json.items-7efb591d-ac6...
# 22  accel_walking_outbound.json.items-c921cf75-eda...
# 23  accel_walking_outbound.json.items-e02f263e-9f5...
# 24  accel_walking_outbound.json.items-37f6254f-a6c...
# 25  accel_walking_outbound.json.items-642ff54c-45d...
# 26  accel_walking_outbound.json.items-0ad25211-672...
# 27  accel_walking_outbound.json.items-3c20460f-821...
# 28  accel_walking_outbound.json.items-396ad86f-27a...
# 29  accel_walking_outbound.json.items-d385441e-db8...
# ..                                                ...
# 70  accel_walking_outbound.json.items-018b87b2-8f8...
# 71  accel_walking_outbound.json.items-a2ca3622-7a8...
# 72  accel_walking_outbound.json.items-e44b817a-383...
# 73  accel_walking_outbound.json.items-97165333-834...
# 74  accel_walking_outbound.json.items-b9fe7892-bf5...
# 75  accel_walking_outbound.json.items-9a6e71b6-a7c...
# 76  accel_walking_outbound.json.items-93b5d27d-9e9...
# 77  accel_walking_outbound.json.items-d8f7cab0-2c5...
# 78  accel_walking_outbound.json.items-5f116305-a81...
# 79  accel_walking_outbound.json.items-d1ff19fc-b0a...
# 80  accel_walking_outbound.json.items-3661de43-47c...
# 81  accel_walking_outbound.json.items-2cc4e200-720...
# 82  accel_walking_outbound.json.items-b52192e1-6e9...
# 83  accel_walking_outbound.json.items-9a377ab7-502...
# 84  accel_walking_outbound.json.items-42310fbb-326...
# 85  accel_walking_outbound.json.items-b5a9cb7a-62c...
# 86  accel_walking_outbound.json.items-dd7c6f31-8ed...
# 87  accel_walking_outbound.json.items-d9f8a43e-e9b...
# 88  accel_walking_outbound.json.items-fdb57803-2aa...
# 89  accel_walking_outbound.json.items-49b353eb-681...
# 90  accel_walking_outbound.json.items-31b769d2-a4b...
# 91  accel_walking_outbound.json.items-28e5c24f-c82...
# 92  accel_walking_outbound.json.items-d74ef036-5a0...
# 93  accel_walking_outbound.json.items-8df0c54f-e84...
# 94  accel_walking_outbound.json.items-7630b114-7e7...
# 95  accel_walking_outbound.json.items-916e9c11-362...
# 96  accel_walking_outbound.json.items-fdf84ed8-a61...
# 97  accel_walking_outbound.json.items-2866aa42-820...
# 98  accel_walking_outbound.json.items-226d017f-0c3...
# 99  accel_walking_outbound.json.items-dcad1bc8-365...
#
# [100 rows x 17 columns]
